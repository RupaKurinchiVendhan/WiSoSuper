# %%
# %matplotlib inline
import h5pyd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import interpolate

# %%
# Open the wind data "file"
# server endpoint, username, password is found via a config file
f = h5pyd.File("/nrel/wtk-us.h5", 'r')

# %%
f.attrs['history']   # attributes can be used to provide desriptions of the content
# Out:
# 'Produced by 3TIER, Inc. under NREL subcontract AGV-2-22460-01'

# %%
dset = f['windspeed_60m']

# %%
dset.id.id  # if this is an int, then you are using h5py!

# %%
dset.shape
# Out:
# (61368, 1602, 2976)

# %%
dset.dtype

# %%
dset.chunks

# %%
dset.shape[0] * dset.shape[1] * dset.shape[2] * 4  # 155 GB!

# %%
(dset.shape[0] * dset.shape[1] * dset.shape[2]) // (dset.chunks[0] * dset.chunks[1] * dset.chunks[2])  # lots a chunks

# %%
dset.shape[1] * dset.shape[2] * 4  # 18 MB per slice

# %%
# %time data = dset[1797,::8,::8]
# Out:
# Wall time: 2.37 s

# %%
plt.imshow(data, origin="lower")

# %%
# %time next_data = dset[1799,::8,::8]
# Out:
# Wall time: 1.08 s

# %%
plt.imshow(next_data, origin="lower")

# %%
# %time data = dset[2199,1100:1400,2000:2400]  # full-rez subset
# Out:
# Wall time: 1.96 s

# %%
coords = f['coordinates']

# %%
coord_data = coords[1601]

# %%
len(coord_data)
# Out:
# 2976

# %%
lat = [x[0] for x in coord_data]
print(max(lat))
print(min(lat))
# Out:
# 53.342793
# 45.97596

# %%
lon = [x[1] for x in coord_data]
print(max(lon))
print(min(lon))
# Out:
# -54.261658
# -137.738342

# %%
plt.imshow(data, origin="lower")

# %%
# %time tseries = dset[:, 801, 600]
# Out:
# Wall time: 12.6 s

# %%
tseries.shape

# %%
day_tseries = dset[::24, 800, 600]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\dataset.py in __getitem__(self, args)
#     849                     try:
# --> 850                         rsp = self.GET(req, params=params, format="binary")
#     851                     except IOError as ioe:
#
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\base.py in GET(self, req, params, use_cache, format)
#     892             self.log.info("Got response: {}".format(rsp.status_code))
# --> 893             raise IOError(rsp.status_code, rsp.reason)
#     894         if 'Content-Type' in rsp.headers and rsp.headers['Content-Type'] == "application/octet-stream":
#
# OSError: [Errno 429] Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-b71adcce371b> in <module>
# ----> 1 day_tseries = dset[::24, 800, 600]
#
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\dataset.py in __getitem__(self, args)
#     857                             break
#     858                         else:
# --> 859                             raise IOError("Error retrieving data: {}".format(ioe.errno))
#     860                     if type(rsp) is bytes:
#     861                         # got binary response
#
# OSError: Error retrieving data: 429

# %%
tseries[0:10]
# Out:
# array([ 2.8840027,  1.0162659,  2.5177765,  4.861595 ,  6.0060425,
#         5.648979 ,  6.1800003,  8.539078 ,  9.756767 , 11.96936  ],
#       dtype=float32)

# %%
len(tseries)   # 365 days * 24 hours * 7 years
# Out:
# 61368

# %%
x = range(dset.shape[0])
plt.plot(x[0:500], tseries[0:500])

# %%
tseries = dset[:, 100, 1000]
x = range(dset.shape[0])
plt.plot(x[0:24], tseries[0:24])

# %%
tseries = dset[:, 400, 600]
x = range(dset.shape[0])
plt.plot(x[0:48], tseries[0:48])

# %%
tseries = dset[:, 300, 600]
x = range(dset.shape[0])
plt.plot(x[0:48], tseries[0:48])

# %%
t = x[0:50]
y = tseries[0:50]
temp = interpolate.splrep(t, y, s=0)
tnew = np.arange(0, np.pi**2, np.pi/100)
ynew = interpolate.splev(tnew, temp, der=0)
# Out:
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.figure()
  
plt.plot(t, y, '*', tnew, ynew, tnew, np.sin(tnew),
         t, y, 'b', color="green")
  
plt.legend(['Linear', 'Cubic Spline', 'True'])
# plt.axis([-0.1, 6.5, -1.1, 1.1])
plt.title('Cubic-spline Interpolation in Python')
plt.show()
# Out:
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   after removing the cwd from sys.path.

# %%
import dask.array as da
chunks=(1, 400,600)
x = da.from_array(dset, chunks=chunks)

# %%
from random import randint
ntimes=dset.shape[0]
tstep = randint(0, ntimes-1)    #read another random time step
# %time data = x[tstep,::8,::8]
# Out:
# Wall time: 16.8 ms

# %%
# %time plt.imshow(data, origin="lower")
# Out:
# Wall time: 3.29 s

# %%
dni

# %%
nsrdb = h5pyd.File("/nrel/nsrdb/v3/nsrdb_2012.h5", 'r')

# %%
dset2 = nsrdb['dni']

# %%
dset2.shape
# Out:
# (17568, 2018392)

# %%
data2 = dset2[1797,::8,::8]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-96eb0f12bac7> in <module>
# ----> 1 data2 = dset2[1797,::8,::8]
#
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\dataset.py in __getitem__(self, args)
#     724
#     725         # Perform the dataspace selection
# --> 726         selection = sel.select(self, args)
#     727         self.log.debug("selection_constructor")
#     728
#
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\selections.py in select(obj, args)
#     108
#     109     sel = SimpleSelection(obj.shape)
# --> 110     sel[args]
#     111     return sel
#     112
#
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\selections.py in __getitem__(self, args)
#     337             return self
#     338
# --> 339         start, count, step, scalar = _handle_simple(self._shape,args)
#     340         self._sel = (start, count, step, scalar)
#     341
#
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\selections.py in _handle_simple(shape, args)
#     566         selected.
#     567     """
# --> 568     args = _expand_ellipsis(args, len(shape))
#     569
#     570     start = []
#
# c:\users\rupak\appdata\local\programs\python\python37\lib\site-packages\h5pyd\_hl\selections.py in _expand_ellipsis(args, rank)
#     553
#     554     if len(final_args) > rank:
# --> 555         raise TypeError("Argument sequence too long")
#     556
#     557     return final_args
#
# TypeError: Argument sequence too long
